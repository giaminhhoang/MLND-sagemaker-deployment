# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# "I watch LOTS of bad films, LOTS!!!!!! It's kind of a hobby, really. Almost every Saturday nite a group of friends and I get together and watch trash from around the globe - ANYTHING. Turkish super hero movies, vampire flicks from Brazil, Italian gorilla transplant movies, Kevin Costner films, ANYTHING (except maybe Raising Helen) but Ihave never seen a WORST film than THEODORE REX. Never. And it's not even entertainingly bad in an Ed Wood kinda way - it just SUCKS. Now this film was famous in Hollywood at the time it was made because Whoopi took off the gloves and made it clear to the press and anyone else who would listen that she HATED THIS PIECE OF CRAP = she tried to get out of her contract, she whined, she moaned but nonetheless they pour her fat butt into this leather skin tight futuristic cop uniform that is ghastly to see, yikes!!!! And you can just see her seething during takes - doing everything but looking off camera for her agent so she can scream at him. The dinosaur has about three facial expressions and the script is so horrible a third grade class could do a better job if promised cookies."

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Wrote preprocessed data to cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.externals import joblib
import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Wrote features to cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

test_y = pd.DataFrame(test_y)
test_X = pd.DataFrame(test_X)

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

# pd.concat([test_y, test_X], axis=1).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False) wrong!!!
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %%
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating a hypertuned XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. As in the Boston Housing notebook, the first step is to create an estimator object which will be used as the *base* of your hyperparameter tuning job.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container, # The name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                        # Where to save the output (the model artifacts)
                                    sagemaker_session=session) # The current SageMaker session

# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='binary:logistic',
                        early_stopping_rounds=10,
                        num_round=500)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ### (TODO) Create the hyperparameter tuner
#
# Now that the base estimator has been set up we need to construct a hyperparameter tuner object which we will use to request SageMaker construct a hyperparameter tuning job.
#
# **Note:** Training a single sentiment analysis XGBoost model takes longer than training a Boston Housing XGBoost model so if you don't want the hyperparameter tuning job to take too long, make sure to not set the total number of models (jobs) too high.

# %%
# First, make sure to import the relevant objects used to construct the tuner
from sagemaker.tuner import IntegerParameter, ContinuousParameter, HyperparameterTuner

# TODO: Create the hyperparameter tuner object

xgb_hyperparameter_tuner = HyperparameterTuner(estimator = xgb, # The estimator object to use as the basis for the training jobs.
                                               objective_metric_name = 'validation:rmse', # The metric used to compare trained models.
                                               objective_type = 'Minimize', # Whether we wish to minimize or maximize the metric.
                                               max_jobs = 20, # The total number of models to train
                                               max_parallel_jobs = 3, # The number of models to train in parallel
                                               hyperparameter_ranges = {
                                                    'max_depth': IntegerParameter(3, 12),
                                                    'eta'      : ContinuousParameter(0.05, 0.5),
                                                    'min_child_weight': IntegerParameter(2, 8),
                                                    'subsample': ContinuousParameter(0.5, 0.9),
                                                    'gamma': ContinuousParameter(0, 10),
                                               })

# %% [markdown]
# ### Fit the hyperparameter tuner
#
# Now that the hyperparameter tuner object has been constructed, it is time to fit the various models and find the best performing model.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
xgb_hyperparameter_tuner.fit({'train': s3_input_train, 'validation': s3_input_validation})

# %% [markdown]
# Remember that the tuning job is constructed and run in the background so if we want to see the progress of our training job we need to call the `wait()` method.

# %%
xgb_hyperparameter_tuner.wait()
# Out:
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................!

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've run our hyperparameter tuning job, it's time to see how well the best performing model actually performs. To do this we will use SageMaker's Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# Remember that in order to create a transformer object to perform the batch transform job, we need a trained estimator object. We can do that using the `attach()` method, creating an estimator object which is attached to the best trained job.

# %%
# TODO: Create a new estimator object attached to the best training job found during hyperparameter tuning
xgb_attached = sagemaker.estimator.Estimator.attach(xgb_hyperparameter_tuner.best_training_job())
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2020-09-14 23:30:50 Starting - Preparing the instances for training
# 2020-09-14 23:30:50 Downloading - Downloading input data
# 2020-09-14 23:30:50 Training - Training image download completed. Training in progress.
# 2020-09-14 23:30:50 Uploading - Uploading generated training model
# 2020-09-14 23:30:50 Completed - Training job completedArguments: train
# [2020-09-14:23:02:15:INFO] Running standalone xgboost training.
# [2020-09-14:23:02:15:INFO] Setting up HPO optimized metric to be : rmse
# [2020-09-14:23:02:15:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8466.03mb
# [2020-09-14:23:02:15:INFO] Determined delimiter of CSV input is ','
# [23:02:15] S3DistributionType set as FullyReplicated
# [23:02:17] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-09-14:23:02:17:INFO] Determined delimiter of CSV input is ','
# [23:02:17] S3DistributionType set as FullyReplicated
# [23:02:18] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [23:02:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 2 pruned nodes, max_depth=12
# [0]#011train-rmse:0.487854#011validation-rmse:0.489856
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [23:02:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 6 pruned nodes, max_depth=12
# [1]#011train-rmse:0.477361#011validation-rmse:0.481182
# [23:02:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 4 pruned nodes, max_depth=12
# [2]#011train-rmse:0.467478#011validation-rmse:0.472921
# [23:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 10 pruned nodes, max_depth=12
# [3]#011train-rmse:0.458642#011validation-rmse:0.465964
# [23:02:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 2 pruned nodes, max_depth=12
# [4]#011train-rmse:0.450705#011validation-rmse:0.459765
# [23:02:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 6 pruned nodes, max_depth=12
# [5]#011train-rmse:0.443167#011validation-rmse:0.454057
# [23:02:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 2 pruned nodes, max_depth=12
# [6]#011train-rmse:0.436065#011validation-rmse:0.448773
# [23:02:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 2 pruned nodes, max_depth=12
# [7]#011train-rmse:0.429714#011validation-rmse:0.443876
# [23:02:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 0 pruned nodes, max_depth=12
# [8]#011train-rmse:0.423734#011validation-rmse:0.439363
# [23:02:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 8 pruned nodes, max_depth=12
# [9]#011train-rmse:0.418168#011validation-rmse:0.435213
# [23:03:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 6 pruned nodes, max_depth=12
# [10]#011train-rmse:0.413007#011validation-rmse:0.431499
# [23:03:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 2 pruned nodes, max_depth=12
# [11]#011train-rmse:0.408302#011validation-rmse:0.427835
# [23:03:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 4 pruned nodes, max_depth=12
# [12]#011train-rmse:0.403803#011validation-rmse:0.424716
# [23:03:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 6 pruned nodes, max_depth=12
# [13]#011train-rmse:0.399225#011validation-rmse:0.421676
# [23:03:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 6 pruned nodes, max_depth=12
# [14]#011train-rmse:0.395177#011validation-rmse:0.418706
# [23:03:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 2 pruned nodes, max_depth=12
# [15]#011train-rmse:0.391366#011validation-rmse:0.41619
# [23:03:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 6 pruned nodes, max_depth=12
# [16]#011train-rmse:0.3877#011validation-rmse:0.413443
# [23:03:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 6 pruned nodes, max_depth=12
# [17]#011train-rmse:0.384196#011validation-rmse:0.410806
# [23:03:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 4 pruned nodes, max_depth=12
# [18]#011train-rmse:0.380831#011validation-rmse:0.408575
# [23:03:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 6 pruned nodes, max_depth=12
# [19]#011train-rmse:0.377624#011validation-rmse:0.406094
# [23:03:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 4 pruned nodes, max_depth=12
# [20]#011train-rmse:0.374751#011validation-rmse:0.403943
# [23:03:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 0 pruned nodes, max_depth=12
# [21]#011train-rmse:0.371429#011validation-rmse:0.401708
# [23:03:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 4 pruned nodes, max_depth=12
# [22]#011train-rmse:0.3689#011validation-rmse:0.399865
# [23:03:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 4 pruned nodes, max_depth=12
# [23]#011train-rmse:0.366259#011validation-rmse:0.397944
# [23:03:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 6 pruned nodes, max_depth=12
# [24]#011train-rmse:0.363552#011validation-rmse:0.396179
# [23:03:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 8 pruned nodes, max_depth=12
# [25]#011train-rmse:0.361046#011validation-rmse:0.394677
# [23:03:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 0 pruned nodes, max_depth=12
# [26]#011train-rmse:0.358169#011validation-rmse:0.392978
# [23:04:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 2 pruned nodes, max_depth=12
# [27]#011train-rmse:0.35538#011validation-rmse:0.391156
# [23:04:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 2 pruned nodes, max_depth=12
# [28]#011train-rmse:0.352817#011validation-rmse:0.389473
# [23:04:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 2 pruned nodes, max_depth=12
# [29]#011train-rmse:0.350416#011validation-rmse:0.387831
# [23:04:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 2 pruned nodes, max_depth=12
# [30]#011train-rmse:0.348187#011validation-rmse:0.386256
# [23:04:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 6 pruned nodes, max_depth=12
# [31]#011train-rmse:0.345939#011validation-rmse:0.385006
# [23:04:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 8 pruned nodes, max_depth=12
# [32]#011train-rmse:0.344165#011validation-rmse:0.383747
# [23:04:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 6 pruned nodes, max_depth=12
# [33]#011train-rmse:0.342462#011validation-rmse:0.382761
# [23:04:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 4 pruned nodes, max_depth=12
# [34]#011train-rmse:0.340102#011validation-rmse:0.381484
# [23:04:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 4 pruned nodes, max_depth=12
# [35]#011train-rmse:0.337838#011validation-rmse:0.38011
# [23:04:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 10 pruned nodes, max_depth=12
# [36]#011train-rmse:0.335996#011validation-rmse:0.378954
# [23:04:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 218 extra nodes, 10 pruned nodes, max_depth=12
# [37]#011train-rmse:0.333902#011validation-rmse:0.377672
# [23:04:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 8 pruned nodes, max_depth=12
# [38]#011train-rmse:0.332284#011validation-rmse:0.376553
# [23:04:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 8 pruned nodes, max_depth=12
# [39]#011train-rmse:0.330529#011validation-rmse:0.375456
# [23:04:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 6 pruned nodes, max_depth=12
# [40]#011train-rmse:0.32865#011validation-rmse:0.37442
# [23:04:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 6 pruned nodes, max_depth=12
# [41]#011train-rmse:0.326969#011validation-rmse:0.37327
# [23:04:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 6 pruned nodes, max_depth=12
# [42]#011train-rmse:0.325255#011validation-rmse:0.372157
# [23:04:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 2 pruned nodes, max_depth=12
# [43]#011train-rmse:0.323357#011validation-rmse:0.371059
# [23:05:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 2 pruned nodes, max_depth=12
# [44]#011train-rmse:0.32189#011validation-rmse:0.370052
# [23:05:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 4 pruned nodes, max_depth=12
# [45]#011train-rmse:0.320036#011validation-rmse:0.36929
# [23:05:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 6 pruned nodes, max_depth=12
# [46]#011train-rmse:0.318428#011validation-rmse:0.368412
# [23:05:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 12 pruned nodes, max_depth=12
# [47]#011train-rmse:0.316831#011validation-rmse:0.367546
# [23:05:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 6 pruned nodes, max_depth=12
# [48]#011train-rmse:0.315412#011validation-rmse:0.366517
# [23:05:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 10 pruned nodes, max_depth=12
# [49]#011train-rmse:0.313995#011validation-rmse:0.36577
# [23:05:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 2 pruned nodes, max_depth=12
# [50]#011train-rmse:0.312226#011validation-rmse:0.364788
# [23:05:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 6 pruned nodes, max_depth=12
# [51]#011train-rmse:0.31069#011validation-rmse:0.363958
# [23:05:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 2 pruned nodes, max_depth=12
# [52]#011train-rmse:0.309361#011validation-rmse:0.363271
# [23:05:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 4 pruned nodes, max_depth=12
# [53]#011train-rmse:0.307833#011validation-rmse:0.362511
# [23:05:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 0 pruned nodes, max_depth=12
# [54]#011train-rmse:0.306424#011validation-rmse:0.361836
# [23:05:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 2 pruned nodes, max_depth=12
# [55]#011train-rmse:0.305301#011validation-rmse:0.361181
# [23:05:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 2 pruned nodes, max_depth=12
# [56]#011train-rmse:0.304089#011validation-rmse:0.360329
# [23:05:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 0 pruned nodes, max_depth=12
# [57]#011train-rmse:0.302922#011validation-rmse:0.359547
# [23:05:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 2 pruned nodes, max_depth=12
# [58]#011train-rmse:0.301243#011validation-rmse:0.358975
# [23:05:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 10 pruned nodes, max_depth=12
# [59]#011train-rmse:0.299914#011validation-rmse:0.358273
# [23:05:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 6 pruned nodes, max_depth=12
# [60]#011train-rmse:0.298705#011validation-rmse:0.357657
# [23:06:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 4 pruned nodes, max_depth=12
# [61]#011train-rmse:0.297398#011validation-rmse:0.356878
# [23:06:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 2 pruned nodes, max_depth=12
# [62]#011train-rmse:0.296455#011validation-rmse:0.356232
# [23:06:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 6 pruned nodes, max_depth=12
# [63]#011train-rmse:0.295433#011validation-rmse:0.355704
# [23:06:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 8 pruned nodes, max_depth=12
# [64]#011train-rmse:0.294426#011validation-rmse:0.355038
# [23:06:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 6 pruned nodes, max_depth=12
# [65]#011train-rmse:0.293441#011validation-rmse:0.354469
# [23:06:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 12 pruned nodes, max_depth=12
# [66]#011train-rmse:0.292185#011validation-rmse:0.353984
# [23:06:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 8 pruned nodes, max_depth=12
# [67]#011train-rmse:0.29064#011validation-rmse:0.35338
# [23:06:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 6 pruned nodes, max_depth=12
# [68]#011train-rmse:0.289601#011validation-rmse:0.352829
# [23:06:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 2 pruned nodes, max_depth=12
# [69]#011train-rmse:0.288359#011validation-rmse:0.352462
# [23:06:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 4 pruned nodes, max_depth=12
# [70]#011train-rmse:0.287474#011validation-rmse:0.352082
# [23:06:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 12 pruned nodes, max_depth=12
# [71]#011train-rmse:0.286077#011validation-rmse:0.351535
# [23:06:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 4 pruned nodes, max_depth=12
# [72]#011train-rmse:0.285152#011validation-rmse:0.351264
# [23:06:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 8 pruned nodes, max_depth=12
# [73]#011train-rmse:0.284216#011validation-rmse:0.350737
# [23:06:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 6 pruned nodes, max_depth=12
# [74]#011train-rmse:0.283372#011validation-rmse:0.350337
# [23:06:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 12 pruned nodes, max_depth=12
# [75]#011train-rmse:0.282167#011validation-rmse:0.349949
# [23:06:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 12 pruned nodes, max_depth=12
# [76]#011train-rmse:0.281222#011validation-rmse:0.349444
# [23:06:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 6 pruned nodes, max_depth=12
# [77]#011train-rmse:0.28024#011validation-rmse:0.348773
# [23:06:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 6 pruned nodes, max_depth=12
# [78]#011train-rmse:0.279435#011validation-rmse:0.348241
# [23:07:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 6 pruned nodes, max_depth=12
# [79]#011train-rmse:0.278148#011validation-rmse:0.347872
# [23:07:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 8 pruned nodes, max_depth=12
# [80]#011train-rmse:0.277254#011validation-rmse:0.347314
# [23:07:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 6 pruned nodes, max_depth=12
# [81]#011train-rmse:0.276397#011validation-rmse:0.346841
# [23:07:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 4 pruned nodes, max_depth=12
# [82]#011train-rmse:0.275581#011validation-rmse:0.346448
# [23:07:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 8 pruned nodes, max_depth=12
# [83]#011train-rmse:0.274658#011validation-rmse:0.345911
# [23:07:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 8 pruned nodes, max_depth=12
# [84]#011train-rmse:0.273571#011validation-rmse:0.345411
# [23:07:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 4 pruned nodes, max_depth=12
# [85]#011train-rmse:0.272477#011validation-rmse:0.344943
# [23:07:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 2 pruned nodes, max_depth=12
# [86]#011train-rmse:0.271823#011validation-rmse:0.344556
# [23:07:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 2 pruned nodes, max_depth=12
# [87]#011train-rmse:0.271056#011validation-rmse:0.344173
# [23:07:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 8 pruned nodes, max_depth=12
# [88]#011train-rmse:0.270159#011validation-rmse:0.34382
# [23:07:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 8 pruned nodes, max_depth=12
# [89]#011train-rmse:0.269295#011validation-rmse:0.34348
# [23:07:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 2 pruned nodes, max_depth=12
# [90]#011train-rmse:0.268455#011validation-rmse:0.34305
# [23:07:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 0 pruned nodes, max_depth=12
# [91]#011train-rmse:0.267526#011validation-rmse:0.342648
# [23:07:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 10 pruned nodes, max_depth=12
# [92]#011train-rmse:0.266865#011validation-rmse:0.342198
# [23:07:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 4 pruned nodes, max_depth=12
# [93]#011train-rmse:0.266201#011validation-rmse:0.341876
# [23:07:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 4 pruned nodes, max_depth=12
# [94]#011train-rmse:0.26556#011validation-rmse:0.34155
# [23:07:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 4 pruned nodes, max_depth=12
# [95]#011train-rmse:0.264857#011validation-rmse:0.341276
# [23:08:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 12 pruned nodes, max_depth=12
# [96]#011train-rmse:0.264272#011validation-rmse:0.340814
# [23:08:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 10 pruned nodes, max_depth=12
# [97]#011train-rmse:0.26337#011validation-rmse:0.34042
# [23:08:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 6 pruned nodes, max_depth=12
# [98]#011train-rmse:0.262789#011validation-rmse:0.339971
# [23:08:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 8 pruned nodes, max_depth=12
# [99]#011train-rmse:0.262134#011validation-rmse:0.339602
# [23:08:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 4 pruned nodes, max_depth=12
# [100]#011train-rmse:0.261542#011validation-rmse:0.339275
# [23:08:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 10 pruned nodes, max_depth=12
# [101]#011train-rmse:0.260824#011validation-rmse:0.339098
# [23:08:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 4 pruned nodes, max_depth=12
# [102]#011train-rmse:0.260255#011validation-rmse:0.338784
# [23:08:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 4 pruned nodes, max_depth=12
# [103]#011train-rmse:0.259649#011validation-rmse:0.338643
# [23:08:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 4 pruned nodes, max_depth=12
# [104]#011train-rmse:0.258755#011validation-rmse:0.338399
# [23:08:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 6 pruned nodes, max_depth=12
# [105]#011train-rmse:0.257684#011validation-rmse:0.338079
# [23:08:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 12 pruned nodes, max_depth=12
# [106]#011train-rmse:0.25687#011validation-rmse:0.337812
# [23:08:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 8 pruned nodes, max_depth=12
# [107]#011train-rmse:0.256339#011validation-rmse:0.3375
# [23:08:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 8 pruned nodes, max_depth=12
# [108]#011train-rmse:0.255678#011validation-rmse:0.337173
# [23:08:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 10 pruned nodes, max_depth=12
# [109]#011train-rmse:0.254907#011validation-rmse:0.336906
# [23:08:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 8 pruned nodes, max_depth=12
# [110]#011train-rmse:0.254038#011validation-rmse:0.336639
# [23:08:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=12
# [111]#011train-rmse:0.253467#011validation-rmse:0.336399
# [23:08:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 4 pruned nodes, max_depth=12
# [112]#011train-rmse:0.252966#011validation-rmse:0.336089
# [23:09:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 4 pruned nodes, max_depth=12
# [113]#011train-rmse:0.252476#011validation-rmse:0.335727
# [23:09:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 8 pruned nodes, max_depth=12
# [114]#011train-rmse:0.251658#011validation-rmse:0.335347
# [23:09:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 2 pruned nodes, max_depth=12
# [115]#011train-rmse:0.250866#011validation-rmse:0.335063
# [23:09:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 6 pruned nodes, max_depth=12
# [116]#011train-rmse:0.249979#011validation-rmse:0.334844
# [23:09:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 6 pruned nodes, max_depth=12
# [117]#011train-rmse:0.249206#011validation-rmse:0.334611
# [23:09:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 6 pruned nodes, max_depth=12
# [118]#011train-rmse:0.24866#011validation-rmse:0.334398
# [23:09:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 2 pruned nodes, max_depth=12
# [119]#011train-rmse:0.248046#011validation-rmse:0.334203
# [23:09:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 4 pruned nodes, max_depth=12
# [120]#011train-rmse:0.247287#011validation-rmse:0.333888
# [23:09:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 2 pruned nodes, max_depth=12
# [121]#011train-rmse:0.246634#011validation-rmse:0.333611
# [23:09:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 2 pruned nodes, max_depth=12
# [122]#011train-rmse:0.24616#011validation-rmse:0.333249
# [23:09:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 2 pruned nodes, max_depth=12
# [123]#011train-rmse:0.245628#011validation-rmse:0.333049
# [23:09:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 12 pruned nodes, max_depth=12
# [124]#011train-rmse:0.24505#011validation-rmse:0.332969
# [23:09:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 2 pruned nodes, max_depth=12
# [125]#011train-rmse:0.244412#011validation-rmse:0.332848
# [23:09:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 8 pruned nodes, max_depth=12
# [126]#011train-rmse:0.243792#011validation-rmse:0.332536
# [23:09:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 10 pruned nodes, max_depth=12
# [127]#011train-rmse:0.243317#011validation-rmse:0.332246
# [23:09:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 6 pruned nodes, max_depth=12
# [128]#011train-rmse:0.242796#011validation-rmse:0.332037
# [23:09:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 4 pruned nodes, max_depth=12
# [129]#011train-rmse:0.242052#011validation-rmse:0.331866
# [23:10:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 14 pruned nodes, max_depth=12
# [130]#011train-rmse:0.241262#011validation-rmse:0.331464
# [23:10:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 4 pruned nodes, max_depth=12
# [131]#011train-rmse:0.240353#011validation-rmse:0.331204
# [23:10:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 4 pruned nodes, max_depth=12
# [132]#011train-rmse:0.239839#011validation-rmse:0.330934
# [23:10:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 2 pruned nodes, max_depth=12
# [133]#011train-rmse:0.239324#011validation-rmse:0.330718
# [23:10:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 6 pruned nodes, max_depth=12
# [134]#011train-rmse:0.238852#011validation-rmse:0.330627
# [23:10:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 4 pruned nodes, max_depth=12
# [135]#011train-rmse:0.238195#011validation-rmse:0.330369
# [23:10:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 160 extra nodes, 4 pruned nodes, max_depth=12
# [136]#011train-rmse:0.237416#011validation-rmse:0.330151
# [23:10:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 6 pruned nodes, max_depth=12
# [137]#011train-rmse:0.236909#011validation-rmse:0.329912
# [23:10:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 4 pruned nodes, max_depth=12
# [138]#011train-rmse:0.236202#011validation-rmse:0.329644
# [23:10:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 8 pruned nodes, max_depth=12
# [139]#011train-rmse:0.235633#011validation-rmse:0.329258
# [23:10:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=12
# [140]#011train-rmse:0.235182#011validation-rmse:0.329109
# [23:10:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 2 pruned nodes, max_depth=12
# [141]#011train-rmse:0.234513#011validation-rmse:0.328946
# [23:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 4 pruned nodes, max_depth=12
# [142]#011train-rmse:0.23391#011validation-rmse:0.328703
# [23:10:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 6 pruned nodes, max_depth=12
# [143]#011train-rmse:0.233467#011validation-rmse:0.328484
# [23:10:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 6 pruned nodes, max_depth=12
# [144]#011train-rmse:0.233009#011validation-rmse:0.32826
# [23:10:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 4 pruned nodes, max_depth=12
# [145]#011train-rmse:0.232666#011validation-rmse:0.328105
# [23:10:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 10 pruned nodes, max_depth=12
# [146]#011train-rmse:0.232256#011validation-rmse:0.32795
# [23:11:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 4 pruned nodes, max_depth=12
# [147]#011train-rmse:0.231677#011validation-rmse:0.32781
# [23:11:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 8 pruned nodes, max_depth=12
# [148]#011train-rmse:0.231273#011validation-rmse:0.327692
# [23:11:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 14 pruned nodes, max_depth=12
# [149]#011train-rmse:0.230884#011validation-rmse:0.327474
# [23:11:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 6 pruned nodes, max_depth=12
# [150]#011train-rmse:0.23039#011validation-rmse:0.327181
# [23:11:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 6 pruned nodes, max_depth=12
# [151]#011train-rmse:0.229926#011validation-rmse:0.327005
# [23:11:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 10 pruned nodes, max_depth=12
# [152]#011train-rmse:0.229577#011validation-rmse:0.326785
# [23:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 4 pruned nodes, max_depth=12
# [153]#011train-rmse:0.228976#011validation-rmse:0.326613
# [23:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 2 pruned nodes, max_depth=12
# [154]#011train-rmse:0.228544#011validation-rmse:0.326438
# [23:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 2 pruned nodes, max_depth=12
# [155]#011train-rmse:0.228062#011validation-rmse:0.326258
# [23:11:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2 pruned nodes, max_depth=12
# [156]#011train-rmse:0.227742#011validation-rmse:0.3262
# [23:11:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 6 pruned nodes, max_depth=12
# [157]#011train-rmse:0.227334#011validation-rmse:0.326005
# [23:11:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=12
# [158]#011train-rmse:0.22703#011validation-rmse:0.325846
# [23:11:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=12
# [159]#011train-rmse:0.226648#011validation-rmse:0.325587
# [23:11:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=12
# [160]#011train-rmse:0.226367#011validation-rmse:0.32539
# [23:11:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 2 pruned nodes, max_depth=12
# [161]#011train-rmse:0.225658#011validation-rmse:0.325105
# [23:11:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 10 pruned nodes, max_depth=12
# [162]#011train-rmse:0.225231#011validation-rmse:0.324932
# [23:11:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 4 pruned nodes, max_depth=12
# [163]#011train-rmse:0.22474#011validation-rmse:0.324733
# [23:12:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=12
# [164]#011train-rmse:0.224291#011validation-rmse:0.324514
# [23:12:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 2 pruned nodes, max_depth=12
# [165]#011train-rmse:0.224025#011validation-rmse:0.324347
# [23:12:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 8 pruned nodes, max_depth=12
# [166]#011train-rmse:0.223657#011validation-rmse:0.324299
# [23:12:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 2 pruned nodes, max_depth=12
# [167]#011train-rmse:0.223283#011validation-rmse:0.324143
# [23:12:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 10 pruned nodes, max_depth=12
# [168]#011train-rmse:0.222725#011validation-rmse:0.323887
# [23:12:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 2 pruned nodes, max_depth=12
# [169]#011train-rmse:0.222302#011validation-rmse:0.3237
# [23:12:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 2 pruned nodes, max_depth=12
# [170]#011train-rmse:0.221747#011validation-rmse:0.323564
# [23:12:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 4 pruned nodes, max_depth=12
# [171]#011train-rmse:0.2211#011validation-rmse:0.3234
# [23:12:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 4 pruned nodes, max_depth=12
# [172]#011train-rmse:0.22077#011validation-rmse:0.32316
# [23:12:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 148 extra nodes, 4 pruned nodes, max_depth=12
# [173]#011train-rmse:0.22023#011validation-rmse:0.32306
# [23:12:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 6 pruned nodes, max_depth=12
# [174]#011train-rmse:0.219728#011validation-rmse:0.322855
# [23:12:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 8 pruned nodes, max_depth=12
# [175]#011train-rmse:0.219031#011validation-rmse:0.322838
# [23:12:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 2 pruned nodes, max_depth=12
# [176]#011train-rmse:0.218728#011validation-rmse:0.322701
# [23:12:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2 pruned nodes, max_depth=12
# [177]#011train-rmse:0.218327#011validation-rmse:0.322525
# [23:12:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=12
# [178]#011train-rmse:0.21791#011validation-rmse:0.322485
# [23:12:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 2 pruned nodes, max_depth=12
# [179]#011train-rmse:0.217491#011validation-rmse:0.322297
# [23:12:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 6 pruned nodes, max_depth=12
# [180]#011train-rmse:0.217074#011validation-rmse:0.322088
# [23:13:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 144 extra nodes, 16 pruned nodes, max_depth=12
# [181]#011train-rmse:0.21641#011validation-rmse:0.321981
# [23:13:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 6 pruned nodes, max_depth=12
# [182]#011train-rmse:0.215979#011validation-rmse:0.321845
# [23:13:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 10 pruned nodes, max_depth=12
# [183]#011train-rmse:0.215554#011validation-rmse:0.32175
# [23:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 4 pruned nodes, max_depth=12
# [184]#011train-rmse:0.215097#011validation-rmse:0.32162
# [23:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 4 pruned nodes, max_depth=12
# [185]#011train-rmse:0.214622#011validation-rmse:0.321452
# [23:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 6 pruned nodes, max_depth=12
# [186]#011train-rmse:0.214332#011validation-rmse:0.321273
# [23:13:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 4 pruned nodes, max_depth=12
# [187]#011train-rmse:0.21397#011validation-rmse:0.321155
# [23:13:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 4 pruned nodes, max_depth=12
# [188]#011train-rmse:0.213712#011validation-rmse:0.321052
# [23:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 6 pruned nodes, max_depth=12
# [189]#011train-rmse:0.213347#011validation-rmse:0.320959
# [23:13:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 12 pruned nodes, max_depth=12
# [190]#011train-rmse:0.212933#011validation-rmse:0.320906
# [23:13:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 10 pruned nodes, max_depth=12
# [191]#011train-rmse:0.212667#011validation-rmse:0.320808
# [23:13:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 6 pruned nodes, max_depth=12
# [192]#011train-rmse:0.212278#011validation-rmse:0.320719
# [23:13:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 12 pruned nodes, max_depth=12
# [193]#011train-rmse:0.211753#011validation-rmse:0.320458
# [23:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=12
# [194]#011train-rmse:0.211367#011validation-rmse:0.320295
# [23:13:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 4 pruned nodes, max_depth=12
# [195]#011train-rmse:0.211102#011validation-rmse:0.320254
# [23:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 2 pruned nodes, max_depth=12
# [196]#011train-rmse:0.210554#011validation-rmse:0.320216
# [23:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=12
# [197]#011train-rmse:0.210233#011validation-rmse:0.320134
# [23:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=12
# [198]#011train-rmse:0.210011#011validation-rmse:0.320024
# [23:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 10 pruned nodes, max_depth=12
# [199]#011train-rmse:0.209593#011validation-rmse:0.319936
# [23:14:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=12
# [200]#011train-rmse:0.209342#011validation-rmse:0.319881
# [23:14:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 4 pruned nodes, max_depth=12
# [201]#011train-rmse:0.208934#011validation-rmse:0.319729
# [23:14:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 6 pruned nodes, max_depth=12
# [202]#011train-rmse:0.208645#011validation-rmse:0.319675
# [23:14:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 6 pruned nodes, max_depth=12
# [203]#011train-rmse:0.208403#011validation-rmse:0.319565
# [23:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=12
# [204]#011train-rmse:0.20819#011validation-rmse:0.319402
# [23:14:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 4 pruned nodes, max_depth=12
# [205]#011train-rmse:0.207565#011validation-rmse:0.319203
# [23:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 4 pruned nodes, max_depth=12
# [206]#011train-rmse:0.206936#011validation-rmse:0.319127
# [23:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 8 pruned nodes, max_depth=12
# [207]#011train-rmse:0.206648#011validation-rmse:0.319073
# [23:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=12
# [208]#011train-rmse:0.20645#011validation-rmse:0.318987
# [23:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 6 pruned nodes, max_depth=12
# [209]#011train-rmse:0.206124#011validation-rmse:0.318892
# [23:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 6 pruned nodes, max_depth=12
# [210]#011train-rmse:0.205773#011validation-rmse:0.318805
# [23:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 4 pruned nodes, max_depth=12
# [211]#011train-rmse:0.205521#011validation-rmse:0.318749
# [23:14:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 6 pruned nodes, max_depth=12
# [212]#011train-rmse:0.205216#011validation-rmse:0.318688
# [23:14:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=12
# [213]#011train-rmse:0.20499#011validation-rmse:0.318643
# [23:14:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 8 pruned nodes, max_depth=12
# [214]#011train-rmse:0.204766#011validation-rmse:0.31853
# [23:15:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 4 pruned nodes, max_depth=12
# [215]#011train-rmse:0.204415#011validation-rmse:0.318515
# [23:15:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 4 pruned nodes, max_depth=12
# [216]#011train-rmse:0.204123#011validation-rmse:0.318388
# [23:15:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 2 pruned nodes, max_depth=12
# [217]#011train-rmse:0.203716#011validation-rmse:0.31827
# [23:15:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=12
# [218]#011train-rmse:0.203347#011validation-rmse:0.318154
# [23:15:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 4 pruned nodes, max_depth=12
# [219]#011train-rmse:0.203041#011validation-rmse:0.318044
# [23:15:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 12 pruned nodes, max_depth=12
# [220]#011train-rmse:0.202465#011validation-rmse:0.317997
# [23:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 4 pruned nodes, max_depth=12
# [221]#011train-rmse:0.20215#011validation-rmse:0.317939
# [23:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 120 extra nodes, 10 pruned nodes, max_depth=12
# [222]#011train-rmse:0.201739#011validation-rmse:0.317901
# [23:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 8 pruned nodes, max_depth=12
# [223]#011train-rmse:0.201481#011validation-rmse:0.317814
# [23:15:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 6 pruned nodes, max_depth=12
# [224]#011train-rmse:0.20119#011validation-rmse:0.31774
# [23:15:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 2 pruned nodes, max_depth=12
# [225]#011train-rmse:0.200951#011validation-rmse:0.317669
# [23:15:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 8 pruned nodes, max_depth=12
# [226]#011train-rmse:0.200635#011validation-rmse:0.317603
# [23:15:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 6 pruned nodes, max_depth=12
# [227]#011train-rmse:0.200321#011validation-rmse:0.317487
# [23:15:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 4 pruned nodes, max_depth=12
# [228]#011train-rmse:0.199989#011validation-rmse:0.317434
# [23:15:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 8 pruned nodes, max_depth=12
# [229]#011train-rmse:0.19976#011validation-rmse:0.317375
# [23:15:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 2 pruned nodes, max_depth=12
# [230]#011train-rmse:0.199268#011validation-rmse:0.317276
# [23:15:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 16 pruned nodes, max_depth=12
# [231]#011train-rmse:0.198931#011validation-rmse:0.317268
# [23:16:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 6 pruned nodes, max_depth=12
# [232]#011train-rmse:0.198504#011validation-rmse:0.317195
# [23:16:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 6 pruned nodes, max_depth=12
# [233]#011train-rmse:0.198274#011validation-rmse:0.317153
# [23:16:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 8 pruned nodes, max_depth=12
# [234]#011train-rmse:0.198063#011validation-rmse:0.317085
# [23:16:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 4 pruned nodes, max_depth=12
# [235]#011train-rmse:0.197802#011validation-rmse:0.317047
# [23:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 6 pruned nodes, max_depth=12
# [236]#011train-rmse:0.19741#011validation-rmse:0.316979
# [23:16:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 8 pruned nodes, max_depth=12
# [237]#011train-rmse:0.196925#011validation-rmse:0.31691
# [23:16:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 4 pruned nodes, max_depth=12
# [238]#011train-rmse:0.196631#011validation-rmse:0.316838
# [23:16:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=12
# [239]#011train-rmse:0.196451#011validation-rmse:0.316718
# [23:16:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 2 pruned nodes, max_depth=12
# [240]#011train-rmse:0.196197#011validation-rmse:0.31665
# [23:16:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 6 pruned nodes, max_depth=12
# [241]#011train-rmse:0.195934#011validation-rmse:0.316577
# [23:16:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 4 pruned nodes, max_depth=12
# [242]#011train-rmse:0.19563#011validation-rmse:0.31645
# [23:16:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 4 pruned nodes, max_depth=12
# [243]#011train-rmse:0.195455#011validation-rmse:0.31627
# [23:16:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 2 pruned nodes, max_depth=12
# [244]#011train-rmse:0.195261#011validation-rmse:0.316218
# [23:16:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 2 pruned nodes, max_depth=12
# [245]#011train-rmse:0.194964#011validation-rmse:0.316161
# [23:16:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 6 pruned nodes, max_depth=12
# [246]#011train-rmse:0.194603#011validation-rmse:0.316086
# [23:16:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 6 pruned nodes, max_depth=12
# [247]#011train-rmse:0.194238#011validation-rmse:0.315941
# [23:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 14 pruned nodes, max_depth=12
# [248]#011train-rmse:0.193988#011validation-rmse:0.315845
# [23:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 2 pruned nodes, max_depth=12
# [249]#011train-rmse:0.193681#011validation-rmse:0.315741
# [23:17:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=12
# [250]#011train-rmse:0.193425#011validation-rmse:0.315655
# [23:17:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 10 pruned nodes, max_depth=12
# [251]#011train-rmse:0.193147#011validation-rmse:0.315524
# [23:17:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=12
# [252]#011train-rmse:0.192936#011validation-rmse:0.315408
# [23:17:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 2 pruned nodes, max_depth=12
# [253]#011train-rmse:0.192648#011validation-rmse:0.315362
# [23:17:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 2 pruned nodes, max_depth=12
# [254]#011train-rmse:0.192298#011validation-rmse:0.315205
# [23:17:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 2 pruned nodes, max_depth=12
# [255]#011train-rmse:0.19198#011validation-rmse:0.315079
# [23:17:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 2 pruned nodes, max_depth=12
# [256]#011train-rmse:0.19156#011validation-rmse:0.315072
# [23:17:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 6 pruned nodes, max_depth=12
# [257]#011train-rmse:0.191318#011validation-rmse:0.315005
# [23:17:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 6 pruned nodes, max_depth=12
# [258]#011train-rmse:0.191092#011validation-rmse:0.315005
# [23:17:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 2 pruned nodes, max_depth=12
# [259]#011train-rmse:0.190795#011validation-rmse:0.314891
# [23:17:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 4 pruned nodes, max_depth=12
# [260]#011train-rmse:0.190493#011validation-rmse:0.314813
# [23:17:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 8 pruned nodes, max_depth=12
# [261]#011train-rmse:0.189916#011validation-rmse:0.314749
# [23:17:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=12
# [262]#011train-rmse:0.189536#011validation-rmse:0.314573
# [23:17:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=12
# [263]#011train-rmse:0.189289#011validation-rmse:0.314457
# [23:17:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=12
# [264]#011train-rmse:0.189071#011validation-rmse:0.314375
# [23:17:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 6 pruned nodes, max_depth=12
# [265]#011train-rmse:0.188834#011validation-rmse:0.314265
# [23:17:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 4 pruned nodes, max_depth=12
# [266]#011train-rmse:0.188356#011validation-rmse:0.31429
# [23:18:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 10 pruned nodes, max_depth=12
# [267]#011train-rmse:0.187896#011validation-rmse:0.314209
# [23:18:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 10 pruned nodes, max_depth=12
# [268]#011train-rmse:0.187629#011validation-rmse:0.314134
# [23:18:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 12 pruned nodes, max_depth=12
# [269]#011train-rmse:0.187348#011validation-rmse:0.314114
# [23:18:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 14 pruned nodes, max_depth=12
# [270]#011train-rmse:0.186969#011validation-rmse:0.314004
# [23:18:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 12 pruned nodes, max_depth=12
# [271]#011train-rmse:0.186316#011validation-rmse:0.313978
# [23:18:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 10 pruned nodes, max_depth=12
# [272]#011train-rmse:0.185651#011validation-rmse:0.313891
# [23:18:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 2 pruned nodes, max_depth=12
# [273]#011train-rmse:0.185413#011validation-rmse:0.313812
# ...
# [23:25:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 4 pruned nodes, max_depth=12
# [392]#011train-rmse:0.156983#011validation-rmse:0.308204
# [23:25:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 6 pruned nodes, max_depth=12
# [393]#011train-rmse:0.156745#011validation-rmse:0.308186
# [23:25:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=12
# [394]#011train-rmse:0.156579#011validation-rmse:0.308155
# [23:25:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 6 pruned nodes, max_depth=12
# [395]#011train-rmse:0.156401#011validation-rmse:0.308113
# [23:25:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=12
# [396]#011train-rmse:0.156265#011validation-rmse:0.308085
# [23:25:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=12
# [397]#011train-rmse:0.156151#011validation-rmse:0.30809
# [23:25:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 8 pruned nodes, max_depth=12
# [398]#011train-rmse:0.155966#011validation-rmse:0.308075
# [23:25:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 8 pruned nodes, max_depth=12
# [399]#011train-rmse:0.155695#011validation-rmse:0.308009
# [23:25:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=12
# [400]#011train-rmse:0.155549#011validation-rmse:0.307958
# [23:25:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 8 pruned nodes, max_depth=12
# [401]#011train-rmse:0.155456#011validation-rmse:0.307887
# [23:25:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 10 pruned nodes, max_depth=12
# [402]#011train-rmse:0.155162#011validation-rmse:0.307906
# [23:25:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 2 pruned nodes, max_depth=12
# [403]#011train-rmse:0.154887#011validation-rmse:0.30787
# [23:26:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 8 pruned nodes, max_depth=12
# [404]#011train-rmse:0.154634#011validation-rmse:0.307873
# [23:26:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 10 pruned nodes, max_depth=12
# [405]#011train-rmse:0.154347#011validation-rmse:0.307851
# [23:26:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=12
# [406]#011train-rmse:0.154221#011validation-rmse:0.307818
# [23:26:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 2 pruned nodes, max_depth=12
# [407]#011train-rmse:0.154063#011validation-rmse:0.307808
# [23:26:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 6 pruned nodes, max_depth=12
# [408]#011train-rmse:0.153881#011validation-rmse:0.307802
# [23:26:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 8 pruned nodes, max_depth=12
# [409]#011train-rmse:0.153636#011validation-rmse:0.307699
# [23:26:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 4 pruned nodes, max_depth=12
# [410]#011train-rmse:0.153422#011validation-rmse:0.307662
# [23:26:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 8 pruned nodes, max_depth=12
# [411]#011train-rmse:0.153269#011validation-rmse:0.307656
# [23:26:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 8 pruned nodes, max_depth=12
# [412]#011train-rmse:0.153033#011validation-rmse:0.307659
# [23:26:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=12
# [413]#011train-rmse:0.152912#011validation-rmse:0.307554
# [23:26:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 6 pruned nodes, max_depth=12
# [414]#011train-rmse:0.152835#011validation-rmse:0.307582
# [23:26:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 2 pruned nodes, max_depth=12
# [415]#011train-rmse:0.152462#011validation-rmse:0.307569
# [23:26:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=12
# [416]#011train-rmse:0.152388#011validation-rmse:0.307468
# [23:26:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 6 pruned nodes, max_depth=12
# [417]#011train-rmse:0.152229#011validation-rmse:0.307397
# [23:26:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=12
# [418]#011train-rmse:0.152123#011validation-rmse:0.307374
# [23:26:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=12
# [419]#011train-rmse:0.151943#011validation-rmse:0.307318
# [23:26:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 10 pruned nodes, max_depth=12
# [420]#011train-rmse:0.151827#011validation-rmse:0.307313
# [23:27:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 8 pruned nodes, max_depth=12
# [421]#011train-rmse:0.151733#011validation-rmse:0.307346
# [23:27:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 4 pruned nodes, max_depth=12
# [422]#011train-rmse:0.151478#011validation-rmse:0.307284
# [23:27:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 8 pruned nodes, max_depth=12
# [423]#011train-rmse:0.151276#011validation-rmse:0.307255
# [23:27:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=12
# [424]#011train-rmse:0.151181#011validation-rmse:0.307248
# [23:27:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=12
# [425]#011train-rmse:0.151083#011validation-rmse:0.307148
# [23:27:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 12 pruned nodes, max_depth=12
# [426]#011train-rmse:0.150831#011validation-rmse:0.307147
# [23:27:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 10 pruned nodes, max_depth=12
# [427]#011train-rmse:0.150649#011validation-rmse:0.307121
# [23:27:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 4 pruned nodes, max_depth=12
# [428]#011train-rmse:0.150439#011validation-rmse:0.307068
# [23:27:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 2 pruned nodes, max_depth=12
# [429]#011train-rmse:0.150285#011validation-rmse:0.306906
# [23:27:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 6 pruned nodes, max_depth=12
# [430]#011train-rmse:0.150108#011validation-rmse:0.306948
# [23:27:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 4 pruned nodes, max_depth=12
# [431]#011train-rmse:0.14993#011validation-rmse:0.306945
# [23:27:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 10 pruned nodes, max_depth=12
# [432]#011train-rmse:0.149797#011validation-rmse:0.306971
# [23:27:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 8 pruned nodes, max_depth=12
# [433]#011train-rmse:0.149574#011validation-rmse:0.306953
# [23:27:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 4 pruned nodes, max_depth=12
# [434]#011train-rmse:0.149478#011validation-rmse:0.306932
# [23:27:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 6 pruned nodes, max_depth=12
# [435]#011train-rmse:0.149272#011validation-rmse:0.306859
# [23:27:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 8 pruned nodes, max_depth=12
# [436]#011train-rmse:0.149163#011validation-rmse:0.306828
# [23:27:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 14 pruned nodes, max_depth=12
# [437]#011train-rmse:0.148959#011validation-rmse:0.306743
# [23:28:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 4 pruned nodes, max_depth=12
# [438]#011train-rmse:0.148837#011validation-rmse:0.306736
# [23:28:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 2 pruned nodes, max_depth=12
# [439]#011train-rmse:0.148675#011validation-rmse:0.30671
# [23:28:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 6 pruned nodes, max_depth=12
# [440]#011train-rmse:0.148466#011validation-rmse:0.3067
# [23:28:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 6 pruned nodes, max_depth=12
# [441]#011train-rmse:0.148326#011validation-rmse:0.306775
# [23:28:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 14 pruned nodes, max_depth=12
# [442]#011train-rmse:0.148188#011validation-rmse:0.30676
# [23:28:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 8 pruned nodes, max_depth=12
# [443]#011train-rmse:0.148051#011validation-rmse:0.306735
# [23:28:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2 pruned nodes, max_depth=12
# [444]#011train-rmse:0.147907#011validation-rmse:0.306654
# [23:28:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 8 pruned nodes, max_depth=12
# [445]#011train-rmse:0.147776#011validation-rmse:0.306706
# [23:28:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 10 pruned nodes, max_depth=12
# [446]#011train-rmse:0.147448#011validation-rmse:0.306622
# [23:28:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=12
# [447]#011train-rmse:0.147301#011validation-rmse:0.306563
# [23:28:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=12
# [448]#011train-rmse:0.147166#011validation-rmse:0.306533
# [23:28:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 4 pruned nodes, max_depth=12
# [449]#011train-rmse:0.147012#011validation-rmse:0.306453
# [23:28:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 2 pruned nodes, max_depth=12
# [450]#011train-rmse:0.1468#011validation-rmse:0.306415
# [23:28:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 6 pruned nodes, max_depth=12
# [451]#011train-rmse:0.146618#011validation-rmse:0.306401
# [23:28:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=12
# [452]#011train-rmse:0.146449#011validation-rmse:0.306362
# [23:28:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 6 pruned nodes, max_depth=12
# [453]#011train-rmse:0.14625#011validation-rmse:0.306327
# [23:28:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 10 pruned nodes, max_depth=12
# [454]#011train-rmse:0.14611#011validation-rmse:0.306264
# [23:29:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 10 pruned nodes, max_depth=12
# [455]#011train-rmse:0.145833#011validation-rmse:0.306251
# [23:29:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 16 pruned nodes, max_depth=12
# [456]#011train-rmse:0.145606#011validation-rmse:0.306284
# [23:29:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 4 pruned nodes, max_depth=12
# [457]#011train-rmse:0.145489#011validation-rmse:0.306256
# [23:29:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 6 pruned nodes, max_depth=12
# [458]#011train-rmse:0.145368#011validation-rmse:0.306273
# [23:29:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 8 pruned nodes, max_depth=12
# [459]#011train-rmse:0.145248#011validation-rmse:0.30629
# [23:29:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 8 pruned nodes, max_depth=12
# [460]#011train-rmse:0.145042#011validation-rmse:0.306275
# [23:29:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 2 pruned nodes, max_depth=12
# [461]#011train-rmse:0.144931#011validation-rmse:0.30628
# [23:29:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=12
# [462]#011train-rmse:0.144787#011validation-rmse:0.306184
# [23:29:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 6 pruned nodes, max_depth=12
# [463]#011train-rmse:0.144657#011validation-rmse:0.30617
# [23:29:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=12
# [464]#011train-rmse:0.144549#011validation-rmse:0.306131
# [23:29:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 12 pruned nodes, max_depth=12
# [465]#011train-rmse:0.144259#011validation-rmse:0.306176
# [23:29:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 4 pruned nodes, max_depth=12
# [466]#011train-rmse:0.144101#011validation-rmse:0.3061
# [23:29:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 8 pruned nodes, max_depth=12
# [467]#011train-rmse:0.143823#011validation-rmse:0.306097
# [23:29:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 10 pruned nodes, max_depth=12
# [468]#011train-rmse:0.143549#011validation-rmse:0.306054
# [23:29:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 10 pruned nodes, max_depth=12
# [469]#011train-rmse:0.143362#011validation-rmse:0.306031
# [23:29:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 4 pruned nodes, max_depth=12
# [470]#011train-rmse:0.143246#011validation-rmse:0.306051
# [23:29:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 6 pruned nodes, max_depth=12
# [471]#011train-rmse:0.143088#011validation-rmse:0.30603
# [23:29:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 8 pruned nodes, max_depth=12
# [472]#011train-rmse:0.142983#011validation-rmse:0.305927
# [23:30:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 4 pruned nodes, max_depth=12
# [473]#011train-rmse:0.142808#011validation-rmse:0.305865
# [23:30:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=12
# [474]#011train-rmse:0.142711#011validation-rmse:0.305812
# [23:30:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 12 pruned nodes, max_depth=12
# [475]#011train-rmse:0.142342#011validation-rmse:0.305818
# [23:30:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 4 pruned nodes, max_depth=12
# [476]#011train-rmse:0.142203#011validation-rmse:0.305923
# [23:30:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 4 pruned nodes, max_depth=12
# [477]#011train-rmse:0.142056#011validation-rmse:0.30593
# [23:30:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 10 pruned nodes, max_depth=12
# [478]#011train-rmse:0.141894#011validation-rmse:0.305898
# [23:30:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 6 pruned nodes, max_depth=12
# [479]#011train-rmse:0.141696#011validation-rmse:0.30594
# [23:30:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 10 pruned nodes, max_depth=12
# [480]#011train-rmse:0.141425#011validation-rmse:0.305931
# [23:30:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=12
# [481]#011train-rmse:0.141329#011validation-rmse:0.305928
# [23:30:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 8 pruned nodes, max_depth=12
# [482]#011train-rmse:0.141205#011validation-rmse:0.305875
# [23:30:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 12 pruned nodes, max_depth=12
# [483]#011train-rmse:0.140972#011validation-rmse:0.305852
# [23:30:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=12
# [484]#011train-rmse:0.14083#011validation-rmse:0.305812
# Stopping. Best iteration:
# [474]#011train-rmse:0.142711#011validation-rmse:0.305812
#
# Training seconds: 1761
# Billable seconds: 1761

# %% [markdown]
# Now that we have an estimator object attached to the correct training job, we can proceed as we normally would and create a transformer object.

# %%
# TODO: Create a transformer object from the attached estimator. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.

xgb_transformer = xgb_attached.transformer(instance_count = 1, instance_type = 'ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# ............................2020-09-15T00:13:59.511:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Arguments: serve
# [2020-09-15 00:13:59 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-09-15 00:13:59 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# Arguments: serve
# [2020-09-15 00:13:59 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-09-15 00:13:59 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-09-15 00:13:59 +0000] [1] [INFO] Using worker: gevent
# [2020-09-15 00:13:59 +0000] [36] [INFO] Booting worker with pid: 36
# [2020-09-15 00:13:59 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-09-15:00:13:59:INFO] Model loaded successfully for worker : 36
# [2020-09-15 00:13:59 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-09-15:00:13:59:INFO] Model loaded successfully for worker : 37
# [2020-09-15 00:13:59 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-09-15:00:13:59:INFO] Model loaded successfully for worker : 38
# [2020-09-15 00:13:59 +0000] [1] [INFO] Using worker: gevent
# [2020-09-15 00:13:59 +0000] [36] [INFO] Booting worker with pid: 36
# [2020-09-15 00:13:59 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-09-15:00:13:59:INFO] Model loaded successfully for worker : 36
# [2020-09-15 00:13:59 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-09-15:00:13:59:INFO] Model loaded successfully for worker : 37
# [2020-09-15 00:13:59 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-09-15:00:13:59:INFO] Model loaded successfully for worker : 38
# [2020-09-15:00:13:59:INFO] Model loaded successfully for worker : 39
# [2020-09-15:00:13:59:INFO] Sniff delimiter as ','
# [2020-09-15:00:13:59:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:13:59:INFO] Model loaded successfully for worker : 39
# [2020-09-15:00:13:59:INFO] Sniff delimiter as ','
# [2020-09-15:00:13:59:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:00:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:00:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:00:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:00:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:00:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:00:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:00:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:00:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:01:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:01:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:01:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:01:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:02:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:02:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:02:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:02:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:03:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:03:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:03:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:03:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:04:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:04:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:04:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:04:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:03:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:03:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:03:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:03:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:04:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:04:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:04:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:04:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:06:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:06:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:06:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:06:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:06:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:06:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:06:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:06:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:06:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:06:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:06:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:06:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:06:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:06:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:06:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:06:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:09:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:09:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:09:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:09:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:09:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:09:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:09:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:09:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:11:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:11:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:11:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:11:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:11:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:11:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:11:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:11:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:11:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:11:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:11:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:11:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:11:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:11:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:11:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:11:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:13:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:13:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:13:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:13:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:13:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:13:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:14:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:14:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:14:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:14:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:13:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:13:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:14:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:14:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:14:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:14:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:16:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:16:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:16:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:16:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:16:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:16:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:16:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:16:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:16:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:16:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:16:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:16:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:16:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:16:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:16:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:16:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:18:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:18:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:19:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:19:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:19:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:19:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:18:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:18:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:19:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:19:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:19:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:19:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:21:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:21:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:21:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:21:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:21:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:21:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:21:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:21:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:21:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:21:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:21:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:21:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:21:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:21:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:21:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:21:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:23:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:23:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:23:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:23:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:23:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:23:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:23:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:23:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:23:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:23:INFO] Sniff delimiter as ','
# [2020-09-15:00:14:23:INFO] Determined delimiter of CSV input is ','
# [2020-09-15:00:14:23:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-east-2-444100773610/xgboost-200914-2109-018-ab423b37-2020-09-15-00-09-28-577/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.86968

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
# Out:
# rmdir: failed to remove ‘../data/xgboost’: Directory not empty
